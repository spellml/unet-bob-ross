# %%
# %%writefile ../scripts/download_data.sh
# export KAGGLE_USERNAME=residentmario KAGGLE_KEY=ea4163444bc3b21c1b810b218c385038
# kaggle datasets download residentmario/segmented-bob-ross-images
# unzip segmented-bob-ross-images.zip -d /mnt/segmented-bob-ross-images/
# rm segmented-bob-ross-images.zip
# Out:
# Writing ../scripts/download_data.sh

# %%
# %%bash
# export KAGGLE_USERNAME=residentmario KAGGLE_KEY=ea4163444bc3b21c1b810b218c385038
# kaggle datasets download residentmario/segmented-bob-ross-images
# unzip segmented-bob-ross-images.zip -d /mnt/segmented-bob-ross-images/
# rm segmented-bob-ross-images.zip
# Out:
# ...
#
# Archive:  segmented-bob-ross-images.zip
#   inflating: /mnt/segmented-bob-ross-images/labels.csv
#   inflating: /mnt/segmented-bob-ross-images/train/images/painting10.png
#   inflating: /mnt/segmented-bob-ross-images/train/images/painting101.png
#   inflating: /mnt/segmented-bob-ross-images/train/images/painting103.png
#   inflating: /mnt/segmented-bob-ross-images/train/images/painting105.png
#   inflating: /mnt/segmented-bob-ross-images/train/images/painting109.png
#   inflating: /mnt/segmented-bob-ross-images/train/images/painting110.png
#   inflating: /mnt/segmented-bob-ross-images/train/images/painting111.png
#   inflating: /mnt/segmented-bob-ross-images/train/images/painting112.png
#   inflating: /mnt/segmented-bob-ross-images/train/images/painting115.png
#   inflating: /mnt/segmented-bob-ross-images/train/images/painting116.png
#   inflating: /mnt/segmented-bob-ross-images/train/images/painting117.png
#   inflating: /mnt/segmented-bob-ross-images/train/images/painting118.png
# ...
